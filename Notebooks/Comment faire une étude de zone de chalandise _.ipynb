# %% [markdown]
# # Comment faire une étude de zone de chalandise ?

# %% [markdown]
# # 1. Qu'est ce que c'est que ce fichier ?
#
#
# - Ce fichier est un *notebook* et permet d'exécuter du code facilement sur la suite Google.
#
# - Il y a deux types de cellules dans ce "cahier", les **cellules de texte** -comme celle-ci- et les **cellules de code** (en fond grisé).
#
# - Pour exécuter une cellule de code, passer la souris sur les crochets (voir ci-dessous) et appuyer sur le play.
#
# - Vous pouvez tester sur la cellule du dessous(il y aura sans doute un peu de chargement pour initialiser le notebook).

# %%
print('Bravo ! Ca a marché')
# Out:
# Bravo ! Ca a marché

# %% [markdown]
# # 2. Initialisation
#
# La cellule suivante donne accès à google drive.
#
# - Lancer la cellule
# - Une nouvelle page va apparaître
# - Cliquer sur accepter pour donner la permission

# %%
from google.colab import drive
import os

drive.mount('/content/gdrive')
# %cd '/content/gdrive/Shareddrives/FoodBiome - Team/5. Ressources/Cartographies/Etude de marché/zone-de-chalandise/Notebooks'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Cartographie

# %% [markdown]
# # 3. Déposer le fichier de surface kmz

# %%
# %run "../src/upload_kmz.py"
# Out:
# FileUpload(value=(), accept='.kml', description='Upload')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Documents/Cartographie/src/upload_kmz.py:21
#      18 uploader.observe(on_upload_change, names='value')
#      20 # get the uploaded file
# ---> 21 my_kmz = uploader.value[0]
#      23 # Create a map
#      24 m = folium.Map(location=[46.8011, 1.6794], zoom_start=5)
#
# IndexError: tuple index out of range

# %% [markdown]
# # 3. Calcul de la population
#
#
# Lancez la cellule suivante et suivez les instructions

# %%
# %run "../src/widget_population.py"
# Out:
# Dropdown(description='Select a file:', options=('La Manufacture.kml', 'toulouse.kml', 'agriviva.kml', 'VivaFre…
# Button(description='Calculer la population', style=ButtonStyle())
# Output()

# %% [markdown]
# # 4. Siret sous l'aire
#
# Lancez la cellule suivante et suivez les instructions.
#
# NB : Il est possible de sélectionner plusieurs secteurs d'entrepriser en même temp (*cmd+clic*)

# %%
# %run "../src/widget_entreprises.py"
# Out:
# Dropdown(description='Select a file:', options=('La Manufacture.kml', 'toulouse.kml', 'agriviva.kml', 'VivaFre…
# SelectMultiple(description='Select NAF:', layout=Layout(width='50%'), options=('Accueil de jeunes enfants', 'A…
# Button(button_style='success', description='Valider', icon='check', style=ButtonStyle(), tooltip='Valider la s…
