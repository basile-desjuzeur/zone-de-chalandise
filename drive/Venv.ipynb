# %% [markdown]
# # Venv
#
# Ce notebook a pour but de télécharger un environnement virtuel sur le Drive.
#
# Ce venv sera ensuite ajouté en variable d'environnement à la volée lors de l'éxécution du Colab principal et permettra d'avoir un environnement d'éxécution isolé et donc une application plus robuste.

# %% [markdown]
# # 1. Création du venv

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
# %cd '/content/gdrive/Shareddrives/FoodBiome - Team/5. Ressources/Cartographies/Outil : Cartographie zone de chalandise/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/Shareddrives/FoodBiome - Team/5. Ressources/Cartographies/Outil cartographie

# %%
! pip install virtualenv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 36.9 MB/s eta 0:00:00
# ...

# %%
! virtualenv '/content/gdrive/Shareddrives/FoodBiome - Team/5. Ressources/Cartographies/Outil cartographie/venv_zone_de_chalandise'
# Out:
# created virtual environment CPython3.10.12.final.0-64 in 10094ms
#   creator CPython3Posix(dest=/content/gdrive/Shareddrives/FoodBiome - Team/5. Ressources/Cartographies/Outil cartographie/venv_zone_de_chalandise, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==23.3.1, setuptools==69.0.2, wheel==0.42.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %% [markdown]
# # 2. Vérification du bon fonctionnement

# %%
# !source  ./venv_zone_de_chalandise/bin/activate; pip install lxml==4.9.3 simplekml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 875.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 29.6 MB/s eta 0:00:00
# ...
#   Created wheel for simplekml: filename=simplekml-1.3.6-py3-none-any.whl size=65860 sha256=04cee80457fc9dfeed40b1663014a1b13341ad5a19341555f2e04ae1b6fa97f8
#   Stored in directory: /root/.cache/pip/wheels/16/7c/e6/621a95f24bd1ff987368f1c37881ffe013433ff6b413d87fcb
# Successfully built simplekml
# ...

# %%
import simplekml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-21b6b2a601ce> in <cell line: 1>()
# ----> 1 import simplekml
#
# ModuleNotFoundError: No module named 'simplekml'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import sys

sys.path.append("./venv_zone_de_chalandise/lib/python3.10/site-packages")

# %%
import simplekml

# %% [markdown]
# La procédure fonctionne bien, il n'y a plus qu'à télécharger les bonnes dépendances.

# %% [markdown]
# # 3. Configuration du venv

# %%
# !source  ./venv_zone_de_chalandise/bin/activate; pip install -r './zone-de-chalandise/requirements.txt'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 4.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.2/156.2 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 717.0/717.0 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
! source  ./venv_zone_de_chalandise/bin/activate; pip install geojson

# %%
! source  ./venv_zone_de_chalandise/bin/activate; pip freeze | grep geojson
# Out:
# geojson==3.1.0
